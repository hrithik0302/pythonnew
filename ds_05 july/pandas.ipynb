# %% [markdown]
#    ### Pandas
#
#    chapter 1 - knowing your data

# %%
pip install pandas

# %%
import pandas as pd

# %%
#it is like tab separated file we need to read it .

# %%
itemset = pd.read_csv('data.tsv.txt',sep='\t')

# %%
itemset
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
itemset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df = pd.DataFrame(itemset)
rows = len(df.axes[0])
cols = len(df.axes[1])
  
print("Number of Rows: " + str(rows))
print("Number of Columns: " + str(cols))
# Out:
# Number of Rows: 4622
# Number of Columns: 5

# %%
itemset.shape
# Out:
# (4622, 5)

# %%
itemset
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
itemset["choice_description"].unique()
# Out:
# array([nan, '[Clementine]', '[Apple]', ...,
#        '[Roasted Chili Corn Salsa, [Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Black Beans]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Guacamole]]'],
#       dtype=object)

# %%
itemset["choice_description"].nunique()
# Out:
# 1043

# %%
most_ordered_item = itemset.groupby('choice_description').sum()
most_ordered_item.sort_values(by='quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
itemset["order_id"].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, Length: 4622, dtype: int64>

# %%
itemset["item_name"].value_counts().head()
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: item_name, dtype: int64

# %%
import pandas as pd

# %%
user_data = pd.read_csv("u.user", sep= "|")

# %%
user_data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
euro_data = pd.read_csv('Euro_2012_stats_TEAM.csv')

# %%
euro_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_data.Team.nunique()
# Out:
# 16

# %%
euro_data.iloc[0:8,0:5]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%

# %%
for index_no,column_name in enumerate(euro_data):
    print(index_no,column_name)
# Out:
# 0 Team
# 1 Goals
# 2 Shots on target
# 3 Shots off target
# 4 Shooting Accuracy
# 5 % Goals-to-shots
# 6 Total shots (inc. Blocked)
# 7 Hit Woodwork
# 8 Penalty goals
# 9 Penalties not scored
# 10 Headed goals
# 11 Passes
# 12 Passes completed
# 13 Passing Accuracy
# 14 Touches
# 15 Crosses
# 16 Dribbles
# 17 Corners Taken
# 18 Tackles
# 19 Clearances
# 20 Interceptions
# 21 Clearances off line
# 22 Clean Sheets
# 23 Blocks
# 24 Goals conceded
# 25 Saves made
# 26 Saves-to-shots ratio
# 27 Fouls Won
# 28 Fouls Conceded
# 29 Offsides
# 30 Yellow Cards
# 31 Red Cards
# 32 Subs on
# 33 Subs off
# 34 Players Used

# %%
#index locator helps to get two columns or rows

euro_data.iloc[:,30:32]
# Out:
#     Yellow Cards  Red Cards
# 0              9          0
# 1              7          0
# 2              4          0
# 3              5          0
# 4              6          0
# 5              4          0
# 6              9          1
# 7             16          0
# 8              5          0
# 9              7          1
# 10            12          0
# 11             6          1
# 12             6          0
# 13            11          0
# 14             7          0
# 15             5          0

# %%
euro_data.set_index('Team')
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro_data.shape
# Out:
# (16, 35)

# %%
euro_data.set_index('Team', inplace=Falsw)

# %%
euro_data.shape
# Out:
# (16, 34)

# %%
euro_data
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro_data.loc[['Denmark','France','Greece'],['Shooting Accuracy']]
# Out:
#         Shooting Accuracy
# Team
# Denmark             50.0%
# France              37.9%
# Greece              30.7%

# %%
euro_data.loc[euro_data.Team.isin(['Denmark','France','Greece']),['Shooting Accuracy']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-459556d908d4> in <module>
# ----> 1 euro_data.loc[euro_data.Team.isin(['Denmark','France','Greece']),['Shooting Accuracy']]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Team'

# %%
team_yellow_red = euro_data[['Team', 'Yellow Cards', 'Red Cards']]
team_yellow_red.sort_values('Red Cards', ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
round(team_yellow_red['Yellow Cards'].mean())
# Out:
# 7

# %%
euro_data(euro_data.Team.str.startswith("S"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-09e125265dc9> in <module>
# ----> 1 euro_data(euro_data.Team.str.startswith("S"))
#
# TypeError: 'DataFrame' object is not callable

# %%
team_yellow_red
# Out:
#    Team  Yellow Cards  Red Cards
# 0     S             9          0
# 1     S             7          0
# 2     S             4          0
# 3     S             5          0
# 4     S             6          0
# 5     S             4          0
# 6     S             9          1
# 7     S            16          0
# 8     S             5          0
# 9     S             7          1
# 10    S            12          0
# 11    S             6          1
# 12    S             6          0
# 13    S            11          0
# 14    S             7          0
# 15    S             5          0

# %%
euro_data.describe()
# Out:
#            Goals  Shots on target  Shots off target  \
# count  16.000000        16.000000         16.000000
# mean    4.750000        17.125000         24.937500
# std     2.886751        10.582218         10.680005
# min     1.000000         7.000000         10.000000
# 25%     2.750000         9.750000         18.000000
# 50%     4.500000        13.000000         23.500000
# 75%     5.250000        22.000000         32.250000
# max    12.000000        42.000000         45.000000
#
#        Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# count                   16.000000     16.000000      16.000000
# mean                    54.937500      1.250000       0.187500
# std                     26.065223      1.612452       0.403113
# min                     27.000000      0.000000       0.000000
# 25%                     36.500000      0.000000       0.000000
# 50%                     44.000000      1.000000       0.000000
# ...

# %%
euro_data.ShootingAccuracy.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-214ad98b100a> in <module>
# ----> 1 euro_data.ShootingAccuracy.count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ShootingAccuracy'

# %% [markdown]
# ## Filtering and sorting

# %%
impro
text_file = pd.read_csv('data.tsv.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30709e06f7ce> in <module>
# ----> 1 text_file = pd.read_csv('data.tsv.txt')
#
# NameError: name 'pd' is not defined
