# %%
pip install skipy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement skipy
# ERROR: No matching distribution found for skipy

# %%
import pandas as pd

# %%
GLAXO_data = pd.read_csv('GLAXO.csv')
GLAXO_data
# Out:
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# ...

# %%
BEML_data = pd.read_csv('BEML.csv')

# %%
glaxo_data_set = GLAXO_data[['Date','Close']]
glaxo_data_set
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
beml_data_set = BEML_data[['Date','Close']]

# %%
glaxo_data_set['Date'] = glaxo_data_set.set_index(pd.DatetimeIndex(glaxo_data_set['Date']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-7732661f80f8> in <module>
# ----> 1 glaxo_data_set['Date'] = glaxo_data_set.set_index(pd.DatetimeIndex(glaxo_data_set['Date']))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
glaxo_data_set.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object
